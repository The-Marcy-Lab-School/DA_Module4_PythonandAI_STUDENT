# %% [markdown]
# # Python for Data Analysis & Database Connectivity
#
# This notebook is where the hands-on graded work for this project lives —
# connecting to your own Module 3 database, and doing real relational work
# (joining, grouping, cleaning) on your own data as pandas objects instead
# of more SQL. `starter/tradeoff_comparison.md` and
# `starter/ai_assisted_coding.md` are separate written deliverables, not
# part of this notebook.

# %%
# Given -- imports and the connection module from db_connect.py.
# Run this cell first, every time.
import sys
sys.path.insert(0, ".")

import pandas as pd
from db_connect import query_with_psycopg2, query_with_sqlalchemy

# %% [markdown]
# ## Part 1: Connect & Explore
#
# Write one real query against your own Module 3 database, run it via
# **both** connection methods, and confirm they return the same result.
# Then produce at least 2 real summary statistics from it.

# %%
# TODO: a real query against your own Module 3 schema
my_query = """
TODO
"""

# %%
# TODO: run it via psycopg2
df_psycopg2 = None

# %%
# TODO: run it via SQLAlchemy
df_sqlalchemy = None

# %%
# TODO: confirm both DataFrames actually match -- don't just assume it

# %%
# TODO: at least 2 real summary statistics from your query result
# (e.g. df.describe(), a real .mean()/.median()/.value_counts() -- your
# choice, but they need to be genuinely informative for your own data)

# %% [markdown]
# ## Part 2: Deepen & Clean — Your Own Data, in Pandas
#
# Pick **at least 2 of your own Module 3 tables** — the same database you
# reconnected to above. Pull each one **raw**: `SELECT * FROM <table>`,
# with **no `JOIN` and no `GROUP BY` in the SQL this time** — that's the
# whole point of this part. The joining and grouping happen below, in
# pandas, as real Python objects, not handed back to you already-computed
# by the database.
#
# See [`data/SOURCE.md`](../data/SOURCE.md) for what's actually messy in
# your own domain — don't just take that doc's word for it, confirm it
# yourself against your own live data below.
#
# Tables chosen: TODO, TODO

# %%
# TODO: pull your first table raw -- no JOIN, no GROUP BY
table_1 = None

# %%
# TODO: pull your second table raw -- no JOIN, no GROUP BY
table_2 = None

# %% [markdown]
# ### Inspect both for real
#
# Before fixing anything: `.info()`, `.head()`, `.isna().sum()`, and a
# real duplicate check on each -- including one that drops the ID column
# first, since two rows can be identical in every real way except an
# arbitrary ID.

# %%
# TODO: real inspection of both tables -- .info(), .head(), .isna().sum(),
# a duplicate check on each

# %% [markdown]
# ### Issue 1
#
# What's wrong, specifically (table, column, and how many rows affected),
# and your fix (`dropna`/`fillna`/`drop_duplicates`/other) with the exact
# reasoning:
#
# > TODO

# %%
# TODO: resolve issue 1

# %% [markdown]
# ### Issue 2
#
# Same as above -- specific issue, specific fix, specific reasoning:
#
# > TODO
#
# **If you found rows that look like duplicates except for an ID column**
# — that's a real judgment call, not an automatic drop. Are they actually
# the same event recorded twice, or a real coincidence given the data? Say
# which you concluded and why, specifically, before deciding whether to
# drop them.
#
# **If you're deduplicating and filling missing values on the same
# table** -- do the duplicate check first, before filling anything in.
# Filling a real gap can accidentally make two genuinely different rows
# look identical, which would inflate your duplicate count for the wrong
# reason.

# %%
# TODO: resolve issue 2

# %% [markdown]
# ### Join and aggregate in pandas
#
# Join your **cleaned** tables yourself with `pd.merge()`, then answer a
# real question about your own data with `.groupby()`/`.agg()` --
# deliberately a **different** question than whatever SQL query you wrote
# in Part 1, so this is real new work, not a recompute.
#
# The deepest version of this combines two separate aggregates that a
# single SQL query can't cleanly express in one pass -- for example, sum
# one measure grouped one way in `table_1`, sum a different measure
# grouped the same way in `table_2`, *then* merge the two aggregates and
# compute a ratio between them. Not required, just the strongest version
# of this exercise.
#
# Your real business question: TODO

# %%
# TODO: join your cleaned tables with pd.merge()
merged = None

# %%
# TODO: answer your real question with .groupby()/.agg() on the merged result
result = None

# %% [markdown]
# ### Verify and save
#
# Confirm your before/after row counts and null counts actually changed the
# way you expected -- real `.isna().sum()` output, not a description of
# it -- and confirm your final merged/aggregated result's shape makes
# sense for your data.

# %%
# TODO: real before/after verification, then save:
# result.to_csv("clean_analysis_output.csv", index=False)
